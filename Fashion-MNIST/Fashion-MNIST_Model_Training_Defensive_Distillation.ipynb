# %%
import numpy as np
import pickle
import matplotlib.pyplot as plt
# %matplotlib inline
import tensorflow as tf

# Display the version
print(tf.__version__)

# import and mount Drive
import os
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# 2.13.0
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# get path to folder file is in
# !pip install kora
from kora.drive import get_path
file_path = get_path('17rNCLBHSPszyoaacFSpsFGD5nlP1OBF7')
file_path = '/content/gdrive/' + str(file_path) + '/Fashion-MNIST'
print(file_path)
# Out:
# Requirement already satisfied: kora in /usr/local/lib/python3.10/dist-packages (0.9.20)
# Requirement already satisfied: ipython in /usr/local/lib/python3.10/dist-packages (from kora) (7.34.0)
# Requirement already satisfied: fastcore in /usr/local/lib/python3.10/dist-packages (from kora) (1.5.29)
# Requirement already satisfied: pip in /usr/local/lib/python3.10/dist-packages (from fastcore->kora) (23.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from fastcore->kora) (23.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython->kora) (67.7.2)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython->kora) (0.19.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython->kora) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython->kora) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython->kora) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython->kora) (3.0.39)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython->kora) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython->kora) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython->kora) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython->kora) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython->kora) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython->kora) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->kora) (0.2.6)
# /content/gdrive/My Drive/Personal Projects/Pioneer Academics Research/code/Fashion-MNIST

# %%
# Download the data from tf, unless it's already here.
if not os.path.exists(file_path+'/data/clean'):
  os.mkdir(file_path+'/data/clean')
  (X_train, y_train), (X_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()
  np.save(file_path+'/data/clean/X_train.npy',X_train)
  np.save(file_path+'/data/clean/y_train.npy',y_train)
  np.save(file_path+'/data/clean/X_test.npy',X_test)
  np.save(file_path+'/data/clean/y_test.npy',y_test)
else:
  X_train = np.load(file_path+'/data/clean/X_train.npy')
  y_train = np.load(file_path+'/data/clean/y_train.npy')
  X_test = np.load(file_path+'/data/clean/X_test.npy')
  y_test = np.load(file_path+'/data/clean/y_test.npy')

print("X_train shape", X_train.shape)
print("y_train shape", y_train.shape)
print("X_test shape", X_test.shape)
print("y_test shape", y_test.shape)
# Out:
# X_train shape (60000, 28, 28)
# y_train shape (60000,)
# X_test shape (10000, 28, 28)
# y_test shape (10000,)

# %%
# Converting to float32 and reducing pixel values
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train = X_train / 255.0
X_test = X_test / 255.0

# reshape dataset to have a single channel
X_train = np.expand_dims(X_train, -1)
X_test = np.expand_dims(X_test, -1)

y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

# %%
# Code to train a model
def train(params=[64, 64, 128, 128, 256, 256], labels=y_train, file_name=(file_path + '/models/defensive_distillation.keras'), temperature = 20, num_epochs = 50, lr = 0.0003, drop = 0.2, reg = 1e-4, batch_size=32):
    model = tf.keras.models.Sequential()

    model.add(tf.keras.layers.Conv2D(params[0], (3, 3), input_shape=X_train.shape[1:], padding='same', activation='relu', kernel_regularizer=tf.keras.regularizers.L2(reg)))
    model.add(tf.keras.layers.MaxPooling2D())
    model.add(tf.keras.layers.Dropout(drop))

    model.add(tf.keras.layers.Conv2D(params[1], (3, 3), padding='same', activation='relu', kernel_regularizer=tf.keras.regularizers.L2(reg)))
    model.add(tf.keras.layers.MaxPooling2D())
    model.add(tf.keras.layers.Dropout(drop))
    model.add(tf.keras.layers.Conv2D(params[2], (3, 3), padding='same', activation='relu', kernel_regularizer=tf.keras.regularizers.L2(reg)))
    model.add(tf.keras.layers.MaxPooling2D())
    model.add(tf.keras.layers.Dropout(drop))
    model.add(tf.keras.layers.Conv2D(params[3], (3, 3), padding='same', activation='relu', kernel_regularizer=tf.keras.regularizers.L2(reg)))
    model.add(tf.keras.layers.MaxPooling2D())
    model.add(tf.keras.layers.Dropout(drop))

    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dense(params[4], activation='relu', kernel_regularizer=tf.keras.regularizers.L2(reg)))
    model.add(tf.keras.layers.Dropout(drop))
    model.add(tf.keras.layers.Dense(params[5], activation='relu', kernel_regularizer=tf.keras.regularizers.L2(reg)))
    model.add(tf.keras.layers.Dropout(drop))
    model.add(tf.keras.layers.Dense(10, kernel_regularizer=tf.keras.regularizers.L2(reg)))

    def temperature_cross_entropy(gt, pred):
      loss = tf.nn.softmax_cross_entropy_with_logits(labels=gt, logits=pred/temperature)
      return loss

    model.compile(loss=temperature_cross_entropy,
                  optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
                  metrics=['accuracy'])

    model.summary()

    model.fit(X_train, labels,
              batch_size=batch_size,
              validation_split=0.1,
              epochs=num_epochs,
              shuffle=True,
              verbose=1)

    if file_name != None:
        model.save(file_name)

    return model

# %%
# Create the teacher model
model = train(file_name=(file_path + '/models/distillation_teacher.keras'))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 64)        640
#
#  max_pooling2d (MaxPooling2  (None, 14, 14, 64)        0
#  D)
#
#  dropout (Dropout)           (None, 14, 14, 64)        0
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 64)        36928
#
#  max_pooling2d_1 (MaxPoolin  (None, 7, 7, 64)          0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 7, 7, 64)          0
#
#  conv2d_2 (Conv2D)           (None, 7, 7, 128)         73856
#
#  max_pooling2d_2 (MaxPoolin  (None, 3, 3, 128)         0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 3, 3, 128)         0
#
#  conv2d_3 (Conv2D)           (None, 3, 3, 128)         147584
#
#  max_pooling2d_3 (MaxPoolin  (None, 1, 1, 128)         0
#  g2D)
#
#  dropout_3 (Dropout)         (None, 1, 1, 128)         0
#
#  flatten (Flatten)           (None, 128)               0
#
#  dense (Dense)               (None, 256)               33024
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 256)               65792
#
#  dropout_5 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 360394 (1.37 MB)
# Trainable params: 360394 (1.37 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 1688/1688 [==============================] - 21s 5ms/step - loss: 0.9474 - accuracy: 0.6555 - val_loss: 0.6091 - val_accuracy: 0.7837
# Epoch 2/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.6394 - accuracy: 0.7841 - val_loss: 0.5265 - val_accuracy: 0.8245
# Epoch 3/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.5513 - accuracy: 0.8223 - val_loss: 0.4648 - val_accuracy: 0.8470
# Epoch 4/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.5013 - accuracy: 0.8421 - val_loss: 0.4313 - val_accuracy: 0.8605
# Epoch 5/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.4624 - accuracy: 0.8573 - val_loss: 0.4010 - val_accuracy: 0.8735
# Epoch 6/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.4397 - accuracy: 0.8671 - val_loss: 0.3871 - val_accuracy: 0.8772
# Epoch 7/50
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.4182 - accuracy: 0.8735 - val_loss: 0.3744 - val_accuracy: 0.8895
# Epoch 8/50
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.4025 - accuracy: 0.8795 - val_loss: 0.3563 - val_accuracy: 0.8912
# Epoch 9/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.3888 - accuracy: 0.8858 - val_loss: 0.3470 - val_accuracy: 0.8957
# Epoch 10/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.3795 - accuracy: 0.8899 - val_loss: 0.3389 - val_accuracy: 0.9018
# Epoch 11/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.3697 - accuracy: 0.8919 - val_loss: 0.3347 - val_accuracy: 0.9033
# Epoch 12/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.3593 - accuracy: 0.8970 - val_loss: 0.3373 - val_accuracy: 0.9012
# Epoch 13/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.3504 - accuracy: 0.9007 - val_loss: 0.3246 - val_accuracy: 0.9078
# Epoch 14/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.3459 - accuracy: 0.9023 - val_loss: 0.3277 - val_accuracy: 0.9065
# Epoch 15/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.3415 - accuracy: 0.9047 - val_loss: 0.3124 - val_accuracy: 0.9092
# Epoch 16/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.3336 - accuracy: 0.9072 - val_loss: 0.3094 - val_accuracy: 0.9145
# Epoch 17/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.3286 - accuracy: 0.9097 - val_loss: 0.3056 - val_accuracy: 0.9157
# Epoch 18/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.3264 - accuracy: 0.9114 - val_loss: 0.3209 - val_accuracy: 0.9123
# Epoch 19/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.3228 - accuracy: 0.9136 - val_loss: 0.3097 - val_accuracy: 0.9157
# Epoch 20/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.3165 - accuracy: 0.9153 - val_loss: 0.3023 - val_accuracy: 0.9207
# Epoch 21/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.3147 - accuracy: 0.9171 - val_loss: 0.2999 - val_accuracy: 0.9188
# Epoch 22/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.3098 - accuracy: 0.9176 - val_loss: 0.3138 - val_accuracy: 0.9158
# Epoch 23/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.3068 - accuracy: 0.9196 - val_loss: 0.3020 - val_accuracy: 0.9167
# Epoch 24/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.3039 - accuracy: 0.9213 - val_loss: 0.3036 - val_accuracy: 0.9195
# Epoch 25/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.3019 - accuracy: 0.9222 - val_loss: 0.2936 - val_accuracy: 0.9260
# Epoch 26/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.3017 - accuracy: 0.9214 - val_loss: 0.2987 - val_accuracy: 0.9243
# Epoch 27/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.2975 - accuracy: 0.9251 - val_loss: 0.2923 - val_accuracy: 0.9233
# Epoch 28/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.2952 - accuracy: 0.9245 - val_loss: 0.2966 - val_accuracy: 0.9215
# Epoch 29/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.2926 - accuracy: 0.9274 - val_loss: 0.2979 - val_accuracy: 0.9230
# Epoch 30/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.2876 - accuracy: 0.9277 - val_loss: 0.3024 - val_accuracy: 0.9205
# Epoch 31/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.2907 - accuracy: 0.9276 - val_loss: 0.2874 - val_accuracy: 0.9273
# Epoch 32/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.2873 - accuracy: 0.9296 - val_loss: 0.3021 - val_accuracy: 0.9203
# Epoch 33/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.2871 - accuracy: 0.9294 - val_loss: 0.2935 - val_accuracy: 0.9245
# Epoch 34/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.2862 - accuracy: 0.9309 - val_loss: 0.2894 - val_accuracy: 0.9252
# Epoch 35/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.2814 - accuracy: 0.9315 - val_loss: 0.2930 - val_accuracy: 0.9253
# Epoch 36/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.2802 - accuracy: 0.9320 - val_loss: 0.2883 - val_accuracy: 0.9270
# Epoch 37/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.2804 - accuracy: 0.9325 - val_loss: 0.2967 - val_accuracy: 0.9270
# Epoch 38/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.2789 - accuracy: 0.9333 - val_loss: 0.2898 - val_accuracy: 0.9270
# Epoch 39/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.2782 - accuracy: 0.9334 - val_loss: 0.2909 - val_accuracy: 0.9283
# Epoch 40/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.2782 - accuracy: 0.9335 - val_loss: 0.2917 - val_accuracy: 0.9273
# Epoch 41/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.2743 - accuracy: 0.9365 - val_loss: 0.2939 - val_accuracy: 0.9287
# Epoch 42/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.2760 - accuracy: 0.9349 - val_loss: 0.2933 - val_accuracy: 0.9277
# Epoch 43/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.2732 - accuracy: 0.9360 - val_loss: 0.2889 - val_accuracy: 0.9288
# Epoch 44/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.2703 - accuracy: 0.9382 - val_loss: 0.2916 - val_accuracy: 0.9268
# Epoch 45/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.2717 - accuracy: 0.9364 - val_loss: 0.2918 - val_accuracy: 0.9303
# Epoch 46/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.2703 - accuracy: 0.9382 - val_loss: 0.3029 - val_accuracy: 0.9242
# Epoch 47/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.2708 - accuracy: 0.9390 - val_loss: 0.2994 - val_accuracy: 0.9272
# Epoch 48/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.2693 - accuracy: 0.9381 - val_loss: 0.2991 - val_accuracy: 0.9270
# Epoch 49/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.2683 - accuracy: 0.9399 - val_loss: 0.2995 - val_accuracy: 0.9260
# Epoch 50/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.2681 - accuracy: 0.9393 - val_loss: 0.2974 - val_accuracy: 0.9288

# %%
# Evaluate efficacy of teacher model
model.evaluate(X_test, y_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3185 - accuracy: 0.9218
# [0.31849148869514465, 0.9218000173568726]

# %%
# Create 'soft labels' for Defensive Distillation
y_soft_train = model.predict(X_train, batch_size=32)
y_soft_train = tf.nn.softmax(y_soft_train/20)
print(y_soft_train.shape)
# Out:
# 1875/1875 [==============================] - 3s 2ms/step
# (60000, 10)

# %%
# Create the student (distilled) model
distilled_model = train(labels=y_soft_train, file_name=(file_path + '/models/distillation_student.keras'))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 28, 28, 64)        640
#
#  max_pooling2d_4 (MaxPoolin  (None, 14, 14, 64)        0
#  g2D)
#
#  dropout_6 (Dropout)         (None, 14, 14, 64)        0
#
#  conv2d_5 (Conv2D)           (None, 14, 14, 64)        36928
#
#  max_pooling2d_5 (MaxPoolin  (None, 7, 7, 64)          0
#  g2D)
#
#  dropout_7 (Dropout)         (None, 7, 7, 64)          0
#
#  conv2d_6 (Conv2D)           (None, 7, 7, 128)         73856
#
#  max_pooling2d_6 (MaxPoolin  (None, 3, 3, 128)         0
#  g2D)
#
#  dropout_8 (Dropout)         (None, 3, 3, 128)         0
#
#  conv2d_7 (Conv2D)           (None, 3, 3, 128)         147584
#
#  max_pooling2d_7 (MaxPoolin  (None, 1, 1, 128)         0
#  g2D)
#
#  dropout_9 (Dropout)         (None, 1, 1, 128)         0
#
#  flatten_1 (Flatten)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 256)               33024
#
#  dropout_10 (Dropout)        (None, 256)               0
#
#  dense_4 (Dense)             (None, 256)               65792
#
#  dropout_11 (Dropout)        (None, 256)               0
#
#  dense_5 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 360394 (1.37 MB)
# Trainable params: 360394 (1.37 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 1688/1688 [==============================] - 12s 6ms/step - loss: 0.9406 - accuracy: 0.6676 - val_loss: 0.5789 - val_accuracy: 0.8180
# Epoch 2/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.6071 - accuracy: 0.8111 - val_loss: 0.4781 - val_accuracy: 0.8617
# Epoch 3/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.5191 - accuracy: 0.8503 - val_loss: 0.4259 - val_accuracy: 0.8902
# Epoch 4/50
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.4718 - accuracy: 0.8717 - val_loss: 0.3987 - val_accuracy: 0.9017
# Epoch 5/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.4383 - accuracy: 0.8849 - val_loss: 0.3703 - val_accuracy: 0.9152
# Epoch 6/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.4117 - accuracy: 0.8941 - val_loss: 0.3536 - val_accuracy: 0.9250
# Epoch 7/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.3928 - accuracy: 0.9029 - val_loss: 0.3353 - val_accuracy: 0.9333
# Epoch 8/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.3765 - accuracy: 0.9090 - val_loss: 0.3215 - val_accuracy: 0.9385
# Epoch 9/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.3671 - accuracy: 0.9126 - val_loss: 0.3145 - val_accuracy: 0.9418
# Epoch 10/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.3555 - accuracy: 0.9179 - val_loss: 0.3127 - val_accuracy: 0.9430
# Epoch 11/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.3461 - accuracy: 0.9219 - val_loss: 0.3036 - val_accuracy: 0.9503
# Epoch 12/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.3391 - accuracy: 0.9249 - val_loss: 0.2962 - val_accuracy: 0.9538
# Epoch 13/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.3335 - accuracy: 0.9278 - val_loss: 0.2945 - val_accuracy: 0.9525
# Epoch 14/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.3294 - accuracy: 0.9299 - val_loss: 0.2899 - val_accuracy: 0.9563
# Epoch 15/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.3246 - accuracy: 0.9316 - val_loss: 0.2916 - val_accuracy: 0.9532
# Epoch 16/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.3208 - accuracy: 0.9339 - val_loss: 0.2876 - val_accuracy: 0.9575
# Epoch 17/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.3167 - accuracy: 0.9375 - val_loss: 0.2876 - val_accuracy: 0.9548
# Epoch 18/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.3147 - accuracy: 0.9365 - val_loss: 0.2860 - val_accuracy: 0.9575
# Epoch 19/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.3132 - accuracy: 0.9366 - val_loss: 0.2802 - val_accuracy: 0.9610
# Epoch 20/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.3099 - accuracy: 0.9383 - val_loss: 0.2854 - val_accuracy: 0.9545
# Epoch 21/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.3092 - accuracy: 0.9399 - val_loss: 0.2820 - val_accuracy: 0.9583
# Epoch 22/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.3061 - accuracy: 0.9420 - val_loss: 0.2785 - val_accuracy: 0.9623
# Epoch 23/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.3039 - accuracy: 0.9433 - val_loss: 0.2858 - val_accuracy: 0.9580
# Epoch 24/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.3020 - accuracy: 0.9441 - val_loss: 0.2763 - val_accuracy: 0.9637
# Epoch 25/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.3015 - accuracy: 0.9442 - val_loss: 0.2762 - val_accuracy: 0.9652
# Epoch 26/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.3009 - accuracy: 0.9441 - val_loss: 0.2822 - val_accuracy: 0.9610
# Epoch 27/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.2990 - accuracy: 0.9453 - val_loss: 0.2823 - val_accuracy: 0.9595
# Epoch 28/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.2976 - accuracy: 0.9461 - val_loss: 0.2821 - val_accuracy: 0.9562
# Epoch 29/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.2969 - accuracy: 0.9476 - val_loss: 0.2822 - val_accuracy: 0.9583
# Epoch 30/50
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.2986 - accuracy: 0.9449 - val_loss: 0.2872 - val_accuracy: 0.9550
# Epoch 31/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.2940 - accuracy: 0.9487 - val_loss: 0.2724 - val_accuracy: 0.9643
# Epoch 32/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.2935 - accuracy: 0.9484 - val_loss: 0.2749 - val_accuracy: 0.9613
# Epoch 33/50
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.2940 - accuracy: 0.9473 - val_loss: 0.2837 - val_accuracy: 0.9553
# Epoch 34/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.2930 - accuracy: 0.9494 - val_loss: 0.2736 - val_accuracy: 0.9645
# Epoch 35/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.2913 - accuracy: 0.9488 - val_loss: 0.2823 - val_accuracy: 0.9608
# Epoch 36/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.2909 - accuracy: 0.9494 - val_loss: 0.2694 - val_accuracy: 0.9672
# Epoch 37/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.2905 - accuracy: 0.9503 - val_loss: 0.2705 - val_accuracy: 0.9658
# Epoch 38/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.2892 - accuracy: 0.9506 - val_loss: 0.2709 - val_accuracy: 0.9662
# Epoch 39/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.2892 - accuracy: 0.9501 - val_loss: 0.2728 - val_accuracy: 0.9622
# Epoch 40/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.2888 - accuracy: 0.9504 - val_loss: 0.2721 - val_accuracy: 0.9665
# Epoch 41/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.2891 - accuracy: 0.9501 - val_loss: 0.2704 - val_accuracy: 0.9657
# Epoch 42/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.2873 - accuracy: 0.9517 - val_loss: 0.2696 - val_accuracy: 0.9660
# Epoch 43/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.2853 - accuracy: 0.9532 - val_loss: 0.2688 - val_accuracy: 0.9667
# Epoch 44/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.2863 - accuracy: 0.9524 - val_loss: 0.2806 - val_accuracy: 0.9567
# Epoch 45/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.2869 - accuracy: 0.9516 - val_loss: 0.2674 - val_accuracy: 0.9700
# Epoch 46/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.2856 - accuracy: 0.9517 - val_loss: 0.2692 - val_accuracy: 0.9655
# Epoch 47/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.2851 - accuracy: 0.9527 - val_loss: 0.2714 - val_accuracy: 0.9667
# Epoch 48/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.2851 - accuracy: 0.9529 - val_loss: 0.2668 - val_accuracy: 0.9707
# Epoch 49/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.2842 - accuracy: 0.9540 - val_loss: 0.2670 - val_accuracy: 0.9700
# Epoch 50/50
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.2843 - accuracy: 0.9529 - val_loss: 0.2683 - val_accuracy: 0.9672

# %%
# Evaluate efficacy of student (distilled) model on a set the model has never seen
distilled_model.evaluate(X_test, y_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2951 - accuracy: 0.9179
# [0.2951374053955078, 0.917900025844574]
