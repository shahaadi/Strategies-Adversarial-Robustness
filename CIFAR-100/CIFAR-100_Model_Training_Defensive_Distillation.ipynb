# %%
import numpy as np
import pickle
import matplotlib.pyplot as plt
# %matplotlib inline
import tensorflow as tf

# Display the version
print(tf.__version__)

# import and mount Drive
import os
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# 2.13.0
# Mounted at /content/gdrive

# %%
# get path to folder file is in
# !pip install kora
from kora.drive import get_path
file_path = get_path('17rNCLBHSPszyoaacFSpsFGD5nlP1OBF7')
file_path = '/content/gdrive/' + str(file_path) + '/CIFAR-100'
print(file_path)
# Out:
# Collecting kora
#   Downloading kora-0.9.20-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: ipython in /usr/local/lib/python3.10/dist-packages (from kora) (7.34.0)
# Requirement already satisfied: fastcore in /usr/local/lib/python3.10/dist-packages (from kora) (1.5.29)
# Requirement already satisfied: pip in /usr/local/lib/python3.10/dist-packages (from fastcore->kora) (23.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from fastcore->kora) (23.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython->kora) (67.7.2)
# Collecting jedi>=0.16 (from ipython->kora)
#   Downloading jedi-0.19.0-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 22.3 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython->kora) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython->kora) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython->kora) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython->kora) (3.0.39)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython->kora) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython->kora) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython->kora) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython->kora) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython->kora) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython->kora) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->kora) (0.2.6)
# Installing collected packages: jedi, kora
# Successfully installed jedi-0.19.0 kora-0.9.20
# /content/gdrive/My Drive/Personal Projects/Pioneer Academics Research/code/CIFAR-100

# %%
# Download the data from tf, unless it's already here.
if not os.path.exists(file_path+'/data/clean'):
  os.mkdir(file_path+'/data/clean')
  (X_train, y_train), (X_test, y_test) = tf.keras.datasets.cifar100.load_data()
  np.save(file_path+'/data/clean/X_train.npy',X_train)
  np.save(file_path+'/data/clean/y_train.npy',y_train)
  np.save(file_path+'/data/clean/X_test.npy',X_test)
  np.save(file_path+'/data/clean/y_test.npy',y_test)
else:
  X_train = np.load(file_path+'/data/clean/X_train.npy')
  y_train = np.load(file_path+'/data/clean/y_train.npy')
  X_test = np.load(file_path+'/data/clean/X_test.npy')
  y_test = np.load(file_path+'/data/clean/y_test.npy')

print("X_train shape", X_train.shape)
print("y_train shape", y_train.shape)
print("X_test shape", X_test.shape)
print("y_test shape", y_test.shape)
# Out:
# X_train shape (50000, 32, 32, 3)
# y_train shape (50000, 1)
# X_test shape (10000, 32, 32, 3)
# y_test shape (10000, 1)

# %%
# Converting to float32 and reducing pixel values
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train = X_train / 255.0
X_test = X_test / 255.0

y_train = tf.keras.utils.to_categorical(y_train, 100)
y_test = tf.keras.utils.to_categorical(y_test, 100)

# %%
# Code to train a model
def train(params=[64, 64, 128, 128, 256, 256], labels=y_train, file_name=(file_path + '/models/defensive_distillation.keras'), temperature = 20, num_epochs = 50, lr = 0.0003, drop = 0.2, reg = 1e-4, batch_size=32):
    model = tf.keras.models.Sequential()

    model.add(tf.keras.layers.Conv2D(params[0], (3, 3), input_shape=X_train.shape[1:], padding='same', activation='relu', kernel_regularizer=tf.keras.regularizers.L2(reg)))
    model.add(tf.keras.layers.MaxPooling2D())
    model.add(tf.keras.layers.Dropout(drop))

    model.add(tf.keras.layers.Conv2D(params[1], (3, 3), padding='same', activation='relu', kernel_regularizer=tf.keras.regularizers.L2(reg)))
    model.add(tf.keras.layers.MaxPooling2D())
    model.add(tf.keras.layers.Dropout(drop))
    model.add(tf.keras.layers.Conv2D(params[2], (3, 3), padding='same', activation='relu', kernel_regularizer=tf.keras.regularizers.L2(reg)))
    model.add(tf.keras.layers.MaxPooling2D())
    model.add(tf.keras.layers.Dropout(drop))
    model.add(tf.keras.layers.Conv2D(params[3], (3, 3), padding='same', activation='relu', kernel_regularizer=tf.keras.regularizers.L2(reg)))
    model.add(tf.keras.layers.MaxPooling2D())
    model.add(tf.keras.layers.Dropout(drop))

    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dense(params[4], activation='relu', kernel_regularizer=tf.keras.regularizers.L2(reg)))
    model.add(tf.keras.layers.Dropout(drop))
    model.add(tf.keras.layers.Dense(params[5], activation='relu', kernel_regularizer=tf.keras.regularizers.L2(reg)))
    model.add(tf.keras.layers.Dropout(drop))
    model.add(tf.keras.layers.Dense(100, kernel_regularizer=tf.keras.regularizers.L2(reg)))

    def temperature_cross_entropy(gt, pred):
      loss = tf.nn.softmax_cross_entropy_with_logits(labels=gt, logits=pred/temperature)
      return loss

    model.compile(loss=temperature_cross_entropy,
                  optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
                  metrics=['accuracy'])

    model.summary()

    model.fit(X_train, labels,
              batch_size=batch_size,
              validation_split=0.1,
              epochs=num_epochs,
              shuffle=True,
              verbose=1)

    if file_name != None:
        model.save(file_name)

    return model

# %%
# Create the teacher model
model = train(file_name=(file_path + '/models/distillation_teacher.keras'))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 64)        1792
#
#  max_pooling2d (MaxPooling2  (None, 16, 16, 64)        0
#  D)
#
#  dropout (Dropout)           (None, 16, 16, 64)        0
#
#  conv2d_1 (Conv2D)           (None, 16, 16, 64)        36928
#
#  max_pooling2d_1 (MaxPoolin  (None, 8, 8, 64)          0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 8, 8, 64)          0
#
#  conv2d_2 (Conv2D)           (None, 8, 8, 128)         73856
#
#  max_pooling2d_2 (MaxPoolin  (None, 4, 4, 128)         0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 4, 4, 128)         0
#
#  conv2d_3 (Conv2D)           (None, 4, 4, 128)         147584
#
#  max_pooling2d_3 (MaxPoolin  (None, 2, 2, 128)         0
#  g2D)
#
#  dropout_3 (Dropout)         (None, 2, 2, 128)         0
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 256)               131328
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 256)               65792
#
#  dropout_5 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 100)               25700
#
# =================================================================
# Total params: 482980 (1.84 MB)
# Trainable params: 482980 (1.84 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 1407/1407 [==============================] - 20s 6ms/step - loss: 4.3914 - accuracy: 0.0285 - val_loss: 4.1858 - val_accuracy: 0.0474
# Epoch 2/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 4.1177 - accuracy: 0.0603 - val_loss: 4.0239 - val_accuracy: 0.0796
# Epoch 3/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 3.9644 - accuracy: 0.0850 - val_loss: 3.8834 - val_accuracy: 0.1058
# Epoch 4/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 3.8157 - accuracy: 0.1123 - val_loss: 3.7101 - val_accuracy: 0.1350
# Epoch 5/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 3.7087 - accuracy: 0.1319 - val_loss: 3.6194 - val_accuracy: 0.1500
# Epoch 6/50
# 1407/1407 [==============================] - 8s 5ms/step - loss: 3.6366 - accuracy: 0.1437 - val_loss: 3.5410 - val_accuracy: 0.1658
# Epoch 7/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 3.5624 - accuracy: 0.1580 - val_loss: 3.4827 - val_accuracy: 0.1778
# Epoch 8/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 3.4959 - accuracy: 0.1698 - val_loss: 3.4123 - val_accuracy: 0.1912
# Epoch 9/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 3.4283 - accuracy: 0.1829 - val_loss: 3.3110 - val_accuracy: 0.2092
# Epoch 10/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 3.3625 - accuracy: 0.1980 - val_loss: 3.2655 - val_accuracy: 0.2176
# Epoch 11/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 3.3013 - accuracy: 0.2069 - val_loss: 3.2071 - val_accuracy: 0.2310
# Epoch 12/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 3.2539 - accuracy: 0.2180 - val_loss: 3.1720 - val_accuracy: 0.2396
# Epoch 13/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 3.2001 - accuracy: 0.2292 - val_loss: 3.1253 - val_accuracy: 0.2470
# Epoch 14/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 3.1590 - accuracy: 0.2390 - val_loss: 3.0872 - val_accuracy: 0.2628
# Epoch 15/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 3.1244 - accuracy: 0.2446 - val_loss: 3.0648 - val_accuracy: 0.2598
# Epoch 16/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 3.0885 - accuracy: 0.2545 - val_loss: 3.0017 - val_accuracy: 0.2804
# Epoch 17/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 3.0536 - accuracy: 0.2610 - val_loss: 2.9697 - val_accuracy: 0.2908
# Epoch 18/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 3.0213 - accuracy: 0.2673 - val_loss: 2.9649 - val_accuracy: 0.2894
# Epoch 19/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.9912 - accuracy: 0.2752 - val_loss: 2.9015 - val_accuracy: 0.3028
# Epoch 20/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.9569 - accuracy: 0.2841 - val_loss: 2.9413 - val_accuracy: 0.2974
# Epoch 21/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.9272 - accuracy: 0.2900 - val_loss: 2.8557 - val_accuracy: 0.3172
# Epoch 22/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.9004 - accuracy: 0.2960 - val_loss: 2.8088 - val_accuracy: 0.3264
# Epoch 23/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.8742 - accuracy: 0.2991 - val_loss: 2.7626 - val_accuracy: 0.3400
# Epoch 24/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.8485 - accuracy: 0.3084 - val_loss: 2.8483 - val_accuracy: 0.3232
# Epoch 25/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.8144 - accuracy: 0.3161 - val_loss: 2.7467 - val_accuracy: 0.3390
# Epoch 26/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.7947 - accuracy: 0.3240 - val_loss: 2.7369 - val_accuracy: 0.3440
# Epoch 27/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.7691 - accuracy: 0.3280 - val_loss: 2.7114 - val_accuracy: 0.3490
# Epoch 28/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.7438 - accuracy: 0.3343 - val_loss: 2.6555 - val_accuracy: 0.3642
# Epoch 29/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.7147 - accuracy: 0.3393 - val_loss: 2.6675 - val_accuracy: 0.3642
# Epoch 30/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.6963 - accuracy: 0.3446 - val_loss: 2.6824 - val_accuracy: 0.3590
# Epoch 31/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.6770 - accuracy: 0.3518 - val_loss: 2.6273 - val_accuracy: 0.3796
# Epoch 32/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.6642 - accuracy: 0.3530 - val_loss: 2.5761 - val_accuracy: 0.3866
# Epoch 33/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.6403 - accuracy: 0.3599 - val_loss: 2.6266 - val_accuracy: 0.3726
# Epoch 34/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.6151 - accuracy: 0.3649 - val_loss: 2.5720 - val_accuracy: 0.3860
# Epoch 35/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.6013 - accuracy: 0.3701 - val_loss: 2.5890 - val_accuracy: 0.3858
# Epoch 36/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.5865 - accuracy: 0.3721 - val_loss: 2.5922 - val_accuracy: 0.3828
# Epoch 37/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.5644 - accuracy: 0.3758 - val_loss: 2.5252 - val_accuracy: 0.3920
# Epoch 38/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.5497 - accuracy: 0.3837 - val_loss: 2.5257 - val_accuracy: 0.3974
# Epoch 39/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.5341 - accuracy: 0.3871 - val_loss: 2.5161 - val_accuracy: 0.3984
# Epoch 40/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.5193 - accuracy: 0.3914 - val_loss: 2.4981 - val_accuracy: 0.4086
# Epoch 41/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.5086 - accuracy: 0.3925 - val_loss: 2.4897 - val_accuracy: 0.4118
# Epoch 42/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.4953 - accuracy: 0.3957 - val_loss: 2.4753 - val_accuracy: 0.4134
# Epoch 43/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.4764 - accuracy: 0.4027 - val_loss: 2.5008 - val_accuracy: 0.4104
# Epoch 44/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.4667 - accuracy: 0.4070 - val_loss: 2.4772 - val_accuracy: 0.4084
# Epoch 45/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.4460 - accuracy: 0.4068 - val_loss: 2.4364 - val_accuracy: 0.4204
# Epoch 46/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.4355 - accuracy: 0.4136 - val_loss: 2.4492 - val_accuracy: 0.4172
# Epoch 47/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.4272 - accuracy: 0.4158 - val_loss: 2.4263 - val_accuracy: 0.4254
# Epoch 48/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.4160 - accuracy: 0.4170 - val_loss: 2.4062 - val_accuracy: 0.4362
# Epoch 49/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.3988 - accuracy: 0.4213 - val_loss: 2.4114 - val_accuracy: 0.4326
# Epoch 50/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.3979 - accuracy: 0.4226 - val_loss: 2.4313 - val_accuracy: 0.4316

# %%
# Evaluate efficacy of teacher model
model.evaluate(X_test, y_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 2.3801 - accuracy: 0.4473
# [2.3800530433654785, 0.447299987077713]

# %%
# Create 'soft labels' for Defensive Distillation
y_soft_train = model.predict(X_train, batch_size=32)
y_soft_train = tf.nn.softmax(y_soft_train/20)
print(y_soft_train.shape)
# Out:
# 1563/1563 [==============================] - 3s 2ms/step
# (50000, 100)

# %%
# Create the student (distilled) model
distilled_model = train(labels=y_soft_train, file_name=(file_path + '/models/distillation_student.keras'))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 32, 32, 64)        1792
#
#  max_pooling2d_4 (MaxPoolin  (None, 16, 16, 64)        0
#  g2D)
#
#  dropout_6 (Dropout)         (None, 16, 16, 64)        0
#
#  conv2d_5 (Conv2D)           (None, 16, 16, 64)        36928
#
#  max_pooling2d_5 (MaxPoolin  (None, 8, 8, 64)          0
#  g2D)
#
#  dropout_7 (Dropout)         (None, 8, 8, 64)          0
#
#  conv2d_6 (Conv2D)           (None, 8, 8, 128)         73856
#
#  max_pooling2d_6 (MaxPoolin  (None, 4, 4, 128)         0
#  g2D)
#
#  dropout_8 (Dropout)         (None, 4, 4, 128)         0
#
#  conv2d_7 (Conv2D)           (None, 4, 4, 128)         147584
#
#  max_pooling2d_7 (MaxPoolin  (None, 2, 2, 128)         0
#  g2D)
#
#  dropout_9 (Dropout)         (None, 2, 2, 128)         0
#
#  flatten_1 (Flatten)         (None, 512)               0
#
#  dense_3 (Dense)             (None, 256)               131328
#
#  dropout_10 (Dropout)        (None, 256)               0
#
#  dense_4 (Dense)             (None, 256)               65792
#
#  dropout_11 (Dropout)        (None, 256)               0
#
#  dense_5 (Dense)             (None, 100)               25700
#
# =================================================================
# Total params: 482980 (1.84 MB)
# Trainable params: 482980 (1.84 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 1407/1407 [==============================] - 10s 5ms/step - loss: 4.2437 - accuracy: 0.0644 - val_loss: 3.9802 - val_accuracy: 0.1238
# Epoch 2/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 3.9073 - accuracy: 0.1381 - val_loss: 3.7571 - val_accuracy: 0.1816
# Epoch 3/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 3.7287 - accuracy: 0.1876 - val_loss: 3.5713 - val_accuracy: 0.2388
# Epoch 4/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 3.5862 - accuracy: 0.2302 - val_loss: 3.4683 - val_accuracy: 0.2806
# Epoch 5/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 3.4968 - accuracy: 0.2570 - val_loss: 3.3836 - val_accuracy: 0.3076
# Epoch 6/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 3.4088 - accuracy: 0.2886 - val_loss: 3.2747 - val_accuracy: 0.3478
# Epoch 7/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 3.3299 - accuracy: 0.3169 - val_loss: 3.1751 - val_accuracy: 0.3928
# Epoch 8/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 3.2574 - accuracy: 0.3428 - val_loss: 3.1232 - val_accuracy: 0.4144
# Epoch 9/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 3.1951 - accuracy: 0.3665 - val_loss: 3.0384 - val_accuracy: 0.4488
# Epoch 10/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 3.1440 - accuracy: 0.3894 - val_loss: 2.9872 - val_accuracy: 0.4788
# Epoch 11/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 3.0936 - accuracy: 0.4090 - val_loss: 2.9417 - val_accuracy: 0.4990
# Epoch 12/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 3.0521 - accuracy: 0.4303 - val_loss: 2.9024 - val_accuracy: 0.5218
# Epoch 13/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 3.0154 - accuracy: 0.4449 - val_loss: 2.8683 - val_accuracy: 0.5450
# Epoch 14/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.9855 - accuracy: 0.4614 - val_loss: 2.8294 - val_accuracy: 0.5792
# Epoch 15/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.9590 - accuracy: 0.4773 - val_loss: 2.8287 - val_accuracy: 0.5774
# Epoch 16/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.9383 - accuracy: 0.4871 - val_loss: 2.8090 - val_accuracy: 0.5944
# Epoch 17/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.9211 - accuracy: 0.4954 - val_loss: 2.7884 - val_accuracy: 0.5982
# Epoch 18/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.9047 - accuracy: 0.5064 - val_loss: 2.7687 - val_accuracy: 0.6290
# Epoch 19/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.8902 - accuracy: 0.5125 - val_loss: 2.7929 - val_accuracy: 0.5952
# Epoch 20/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.8750 - accuracy: 0.5221 - val_loss: 2.7520 - val_accuracy: 0.6290
# Epoch 21/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.8678 - accuracy: 0.5267 - val_loss: 2.7422 - val_accuracy: 0.6410
# Epoch 22/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.8587 - accuracy: 0.5348 - val_loss: 2.7325 - val_accuracy: 0.6432
# Epoch 23/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.8500 - accuracy: 0.5406 - val_loss: 2.7272 - val_accuracy: 0.6552
# Epoch 24/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.8408 - accuracy: 0.5433 - val_loss: 2.7339 - val_accuracy: 0.6468
# Epoch 25/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.8347 - accuracy: 0.5499 - val_loss: 2.7230 - val_accuracy: 0.6540
# Epoch 26/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.8287 - accuracy: 0.5547 - val_loss: 2.7050 - val_accuracy: 0.6638
# Epoch 27/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.8246 - accuracy: 0.5590 - val_loss: 2.7048 - val_accuracy: 0.6706
# Epoch 28/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.8179 - accuracy: 0.5588 - val_loss: 2.7055 - val_accuracy: 0.6726
# Epoch 29/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.8093 - accuracy: 0.5675 - val_loss: 2.7228 - val_accuracy: 0.6530
# Epoch 30/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.8069 - accuracy: 0.5674 - val_loss: 2.6943 - val_accuracy: 0.6836
# Epoch 31/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.8026 - accuracy: 0.5694 - val_loss: 2.6869 - val_accuracy: 0.6868
# Epoch 32/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.7996 - accuracy: 0.5682 - val_loss: 2.6942 - val_accuracy: 0.6844
# Epoch 33/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.7957 - accuracy: 0.5737 - val_loss: 2.6899 - val_accuracy: 0.6858
# Epoch 34/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.7944 - accuracy: 0.5799 - val_loss: 2.6887 - val_accuracy: 0.6910
# Epoch 35/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.7907 - accuracy: 0.5786 - val_loss: 2.6884 - val_accuracy: 0.6790
# Epoch 36/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.7868 - accuracy: 0.5784 - val_loss: 2.6852 - val_accuracy: 0.6908
# Epoch 37/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.7842 - accuracy: 0.5817 - val_loss: 2.6803 - val_accuracy: 0.6952
# Epoch 38/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.7819 - accuracy: 0.5837 - val_loss: 2.6864 - val_accuracy: 0.6750
# Epoch 39/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.7800 - accuracy: 0.5853 - val_loss: 2.6955 - val_accuracy: 0.6778
# Epoch 40/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.7758 - accuracy: 0.5878 - val_loss: 2.6795 - val_accuracy: 0.7028
# Epoch 41/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.7740 - accuracy: 0.5904 - val_loss: 2.6765 - val_accuracy: 0.6966
# Epoch 42/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.7731 - accuracy: 0.5894 - val_loss: 2.6975 - val_accuracy: 0.6772
# Epoch 43/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.7718 - accuracy: 0.5895 - val_loss: 2.6925 - val_accuracy: 0.6790
# Epoch 44/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.7679 - accuracy: 0.5924 - val_loss: 2.6688 - val_accuracy: 0.7026
# Epoch 45/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.7682 - accuracy: 0.5945 - val_loss: 2.6922 - val_accuracy: 0.6756
# Epoch 46/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.7647 - accuracy: 0.5963 - val_loss: 2.6769 - val_accuracy: 0.6874
# Epoch 47/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.7636 - accuracy: 0.5952 - val_loss: 2.6747 - val_accuracy: 0.6984
# Epoch 48/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.7619 - accuracy: 0.5977 - val_loss: 2.6765 - val_accuracy: 0.6952
# Epoch 49/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.7602 - accuracy: 0.5970 - val_loss: 2.6771 - val_accuracy: 0.6964
# Epoch 50/50
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.7590 - accuracy: 0.5957 - val_loss: 2.6634 - val_accuracy: 0.7038

# %%
# Evaluate efficacy of student (distilled) model on a set the model has never seen
distilled_model.evaluate(X_test, y_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 2.4262 - accuracy: 0.4088
# [2.4262473583221436, 0.40880000591278076]
