# %%
import numpy as np
import pickle
import matplotlib.pyplot as plt
# %matplotlib inline
import tensorflow as tf

# Display the version
print(tf.__version__)

# import and mount Drive
import os
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# 2.13.0
# Mounted at /content/gdrive

# %%
# get path to folder file is in
# !pip install kora
from kora.drive import get_path
file_path = get_path('17rNCLBHSPszyoaacFSpsFGD5nlP1OBF7')
file_path = '/content/gdrive/' + str(file_path) + '/CIFAR-100'
print(file_path)
# Out:
# Collecting kora
#   Downloading kora-0.9.20-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: ipython in /usr/local/lib/python3.10/dist-packages (from kora) (7.34.0)
# Requirement already satisfied: fastcore in /usr/local/lib/python3.10/dist-packages (from kora) (1.5.29)
# Requirement already satisfied: pip in /usr/local/lib/python3.10/dist-packages (from fastcore->kora) (23.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from fastcore->kora) (23.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython->kora) (67.7.2)
# Collecting jedi>=0.16 (from ipython->kora)
#   Downloading jedi-0.19.0-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 20.6 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython->kora) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython->kora) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython->kora) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython->kora) (3.0.39)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython->kora) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython->kora) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython->kora) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython->kora) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython->kora) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython->kora) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->kora) (0.2.6)
# Installing collected packages: jedi, kora
# Successfully installed jedi-0.19.0 kora-0.9.20
# /content/gdrive/My Drive/Personal Projects/Pioneer Academics Research/code/CIFAR-100

# %%
# Download the data from tf, unless it's already here.
if not os.path.exists(file_path+'/data/clean'):
  os.mkdir(file_path+'/data/clean')
  (X_train, y_train), (X_test, y_test) = tf.keras.datasets.cifar100.load_data()
  np.save(file_path+'/data/clean/X_train.npy',X_train)
  np.save(file_path+'/data/clean/y_train.npy',y_train)
  np.save(file_path+'/data/clean/X_test.npy',X_test)
  np.save(file_path+'/data/clean/y_test.npy',y_test)
else:
  X_train = np.load(file_path+'/data/clean/X_train.npy')
  y_train = np.load(file_path+'/data/clean/y_train.npy')
  X_test = np.load(file_path+'/data/clean/X_test.npy')
  y_test = np.load(file_path+'/data/clean/y_test.npy')

print("X_train shape", X_train.shape)
print("y_train shape", y_train.shape)
print("X_test shape", X_test.shape)
print("y_test shape", y_test.shape)
# Out:
# X_train shape (50000, 32, 32, 3)
# y_train shape (50000, 1)
# X_test shape (10000, 32, 32, 3)
# y_test shape (10000, 1)

# %%
# Reduce pixel values
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train = X_train / 255.0
X_test = X_test / 255.0

# %%
# Display training images
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(X_train[i])
    # The CIFAR labels happen to be arrays,
    # which is why you need the extra index
    plt.xlabel(y_train[i][0])
plt.show()

# %%
# Implement the chosen values in a final model
def train(params=[64, 64, 128, 128, 256, 256], file_name=(file_path + '/models/clean.keras'), num_epochs = 50, lr = 0.0003, drop = 0.2, reg = 1e-4, batch_size=32):
    model = tf.keras.models.Sequential()

    model.add(tf.keras.layers.Conv2D(params[0], (3, 3), input_shape=X_train.shape[1:], padding='same', activation='relu', kernel_regularizer=tf.keras.regularizers.L2(reg)))
    model.add(tf.keras.layers.MaxPooling2D())
    model.add(tf.keras.layers.Dropout(drop))

    model.add(tf.keras.layers.Conv2D(params[1], (3, 3), padding='same', activation='relu', kernel_regularizer=tf.keras.regularizers.L2(reg)))
    model.add(tf.keras.layers.MaxPooling2D())
    model.add(tf.keras.layers.Dropout(drop))
    model.add(tf.keras.layers.Conv2D(params[2], (3, 3), padding='same', activation='relu', kernel_regularizer=tf.keras.regularizers.L2(reg)))
    model.add(tf.keras.layers.MaxPooling2D())
    model.add(tf.keras.layers.Dropout(drop))
    model.add(tf.keras.layers.Conv2D(params[3], (3, 3), padding='same', activation='relu', kernel_regularizer=tf.keras.regularizers.L2(reg)))
    model.add(tf.keras.layers.MaxPooling2D())
    model.add(tf.keras.layers.Dropout(drop))

    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dense(params[4], activation='relu', kernel_regularizer=tf.keras.regularizers.L2(reg)))
    model.add(tf.keras.layers.Dropout(drop))
    model.add(tf.keras.layers.Dense(params[5], activation='relu', kernel_regularizer=tf.keras.regularizers.L2(reg)))
    model.add(tf.keras.layers.Dropout(drop))
    model.add(tf.keras.layers.Dense(100, activation='softmax', kernel_regularizer=tf.keras.regularizers.L2(reg)))

    model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
                  optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
                  metrics=['accuracy'])

    model.summary()

    model.fit(X_train, y_train,
              batch_size=batch_size,
              validation_split=0.1,
              epochs=num_epochs,
              shuffle=True,
              verbose=1)


    if file_name != None:
        model.save(file_name)

    return model

model = train()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 64)        1792
#
#  max_pooling2d (MaxPooling2  (None, 16, 16, 64)        0
#  D)
#
#  dropout (Dropout)           (None, 16, 16, 64)        0
#
#  conv2d_1 (Conv2D)           (None, 16, 16, 64)        36928
#
#  max_pooling2d_1 (MaxPoolin  (None, 8, 8, 64)          0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 8, 8, 64)          0
#
#  conv2d_2 (Conv2D)           (None, 8, 8, 128)         73856
#
#  max_pooling2d_2 (MaxPoolin  (None, 4, 4, 128)         0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 4, 4, 128)         0
#
#  conv2d_3 (Conv2D)           (None, 4, 4, 128)         147584
#
#  max_pooling2d_3 (MaxPoolin  (None, 2, 2, 128)         0
#  g2D)
#
#  dropout_3 (Dropout)         (None, 2, 2, 128)         0
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 256)               131328
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 256)               65792
#
#  dropout_5 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 100)               25700
#
# =================================================================
# Total params: 482980 (1.84 MB)
# Trainable params: 482980 (1.84 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 1407/1407 [==============================] - 27s 7ms/step - loss: 4.3651 - accuracy: 0.0381 - val_loss: 4.0713 - val_accuracy: 0.0760
# Epoch 2/50
# 1407/1407 [==============================] - 10s 7ms/step - loss: 3.8868 - accuracy: 0.1013 - val_loss: 3.6656 - val_accuracy: 0.1482
# Epoch 3/50
# 1407/1407 [==============================] - 8s 6ms/step - loss: 3.5773 - accuracy: 0.1558 - val_loss: 3.3488 - val_accuracy: 0.2040
# Epoch 4/50
# 1407/1407 [==============================] - 10s 7ms/step - loss: 3.3699 - accuracy: 0.1943 - val_loss: 3.2466 - val_accuracy: 0.2336
# Epoch 5/50
# 1407/1407 [==============================] - 11s 8ms/step - loss: 3.2135 - accuracy: 0.2261 - val_loss: 3.0802 - val_accuracy: 0.2584
# Epoch 6/50
# 1407/1407 [==============================] - 9s 6ms/step - loss: 3.0837 - accuracy: 0.2530 - val_loss: 2.9356 - val_accuracy: 0.2968
# Epoch 7/50
# 1407/1407 [==============================] - 9s 7ms/step - loss: 2.9881 - accuracy: 0.2703 - val_loss: 2.8413 - val_accuracy: 0.3150
# Epoch 8/50
# 1407/1407 [==============================] - 10s 7ms/step - loss: 2.8828 - accuracy: 0.2948 - val_loss: 2.8239 - val_accuracy: 0.3280
# Epoch 9/50
# 1407/1407 [==============================] - 9s 6ms/step - loss: 2.8104 - accuracy: 0.3093 - val_loss: 2.6897 - val_accuracy: 0.3478
# Epoch 10/50
# 1407/1407 [==============================] - 10s 7ms/step - loss: 2.7369 - accuracy: 0.3281 - val_loss: 2.6441 - val_accuracy: 0.3600
# Epoch 11/50
# 1407/1407 [==============================] - 9s 7ms/step - loss: 2.6703 - accuracy: 0.3426 - val_loss: 2.5631 - val_accuracy: 0.3786
# Epoch 12/50
# 1407/1407 [==============================] - 9s 6ms/step - loss: 2.6118 - accuracy: 0.3546 - val_loss: 2.5252 - val_accuracy: 0.3834
# Epoch 13/50
# 1407/1407 [==============================] - 9s 7ms/step - loss: 2.5574 - accuracy: 0.3687 - val_loss: 2.4993 - val_accuracy: 0.3910
# Epoch 14/50
# 1407/1407 [==============================] - 10s 7ms/step - loss: 2.5106 - accuracy: 0.3774 - val_loss: 2.5437 - val_accuracy: 0.3828
# Epoch 15/50
# 1407/1407 [==============================] - 9s 7ms/step - loss: 2.4679 - accuracy: 0.3880 - val_loss: 2.4374 - val_accuracy: 0.4052
# Epoch 16/50
# 1407/1407 [==============================] - 9s 6ms/step - loss: 2.4340 - accuracy: 0.3944 - val_loss: 2.3997 - val_accuracy: 0.4174
# Epoch 17/50
# 1407/1407 [==============================] - 10s 7ms/step - loss: 2.3956 - accuracy: 0.4045 - val_loss: 2.3786 - val_accuracy: 0.4232
# Epoch 18/50
# 1407/1407 [==============================] - 9s 7ms/step - loss: 2.3630 - accuracy: 0.4134 - val_loss: 2.3786 - val_accuracy: 0.4256
# Epoch 19/50
# 1407/1407 [==============================] - 9s 7ms/step - loss: 2.3282 - accuracy: 0.4220 - val_loss: 2.3467 - val_accuracy: 0.4330
# Epoch 20/50
# 1407/1407 [==============================] - 10s 7ms/step - loss: 2.3039 - accuracy: 0.4281 - val_loss: 2.3576 - val_accuracy: 0.4300
# Epoch 21/50
# 1407/1407 [==============================] - 10s 7ms/step - loss: 2.2629 - accuracy: 0.4358 - val_loss: 2.3169 - val_accuracy: 0.4396
# Epoch 22/50
# 1407/1407 [==============================] - 9s 6ms/step - loss: 2.2496 - accuracy: 0.4420 - val_loss: 2.3478 - val_accuracy: 0.4382
# Epoch 23/50
# 1407/1407 [==============================] - 10s 7ms/step - loss: 2.2262 - accuracy: 0.4494 - val_loss: 2.3156 - val_accuracy: 0.4412
# Epoch 24/50
# 1407/1407 [==============================] - 10s 7ms/step - loss: 2.2046 - accuracy: 0.4546 - val_loss: 2.2768 - val_accuracy: 0.4494
# Epoch 25/50
# 1407/1407 [==============================] - 9s 6ms/step - loss: 2.1807 - accuracy: 0.4579 - val_loss: 2.2484 - val_accuracy: 0.4580
# Epoch 26/50
# 1407/1407 [==============================] - 10s 7ms/step - loss: 2.1590 - accuracy: 0.4626 - val_loss: 2.2939 - val_accuracy: 0.4474
# Epoch 27/50
# 1407/1407 [==============================] - 10s 7ms/step - loss: 2.1479 - accuracy: 0.4689 - val_loss: 2.2805 - val_accuracy: 0.4484
# Epoch 28/50
# 1407/1407 [==============================] - 9s 6ms/step - loss: 2.1155 - accuracy: 0.4753 - val_loss: 2.2617 - val_accuracy: 0.4554
# Epoch 29/50
# 1407/1407 [==============================] - 10s 7ms/step - loss: 2.1075 - accuracy: 0.4765 - val_loss: 2.2386 - val_accuracy: 0.4670
# Epoch 30/50
# 1407/1407 [==============================] - 10s 7ms/step - loss: 2.0900 - accuracy: 0.4851 - val_loss: 2.2234 - val_accuracy: 0.4604
# Epoch 31/50
# 1407/1407 [==============================] - 9s 6ms/step - loss: 2.0813 - accuracy: 0.4843 - val_loss: 2.2086 - val_accuracy: 0.4684
# Epoch 32/50
# 1407/1407 [==============================] - 9s 7ms/step - loss: 2.0621 - accuracy: 0.4926 - val_loss: 2.2388 - val_accuracy: 0.4608
# Epoch 33/50
# 1407/1407 [==============================] - 10s 7ms/step - loss: 2.0523 - accuracy: 0.4946 - val_loss: 2.2234 - val_accuracy: 0.4702
# Epoch 34/50
# 1407/1407 [==============================] - 9s 6ms/step - loss: 2.0444 - accuracy: 0.4978 - val_loss: 2.2011 - val_accuracy: 0.4740
# Epoch 35/50
# 1407/1407 [==============================] - 10s 7ms/step - loss: 2.0284 - accuracy: 0.5014 - val_loss: 2.1968 - val_accuracy: 0.4782
# Epoch 36/50
# 1407/1407 [==============================] - 10s 7ms/step - loss: 2.0107 - accuracy: 0.5024 - val_loss: 2.2400 - val_accuracy: 0.4730
# Epoch 37/50
# 1407/1407 [==============================] - 9s 6ms/step - loss: 2.0104 - accuracy: 0.5087 - val_loss: 2.2006 - val_accuracy: 0.4712
# Epoch 38/50
# 1407/1407 [==============================] - 9s 7ms/step - loss: 1.9969 - accuracy: 0.5088 - val_loss: 2.2055 - val_accuracy: 0.4810
# Epoch 39/50
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.9892 - accuracy: 0.5114 - val_loss: 2.2026 - val_accuracy: 0.4788
# Epoch 40/50
# 1407/1407 [==============================] - 9s 7ms/step - loss: 1.9845 - accuracy: 0.5138 - val_loss: 2.1981 - val_accuracy: 0.4804
# Epoch 41/50
# 1407/1407 [==============================] - 9s 6ms/step - loss: 1.9629 - accuracy: 0.5198 - val_loss: 2.1657 - val_accuracy: 0.4896
# Epoch 42/50
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.9522 - accuracy: 0.5225 - val_loss: 2.1870 - val_accuracy: 0.4856
# Epoch 43/50
# 1407/1407 [==============================] - 9s 7ms/step - loss: 1.9467 - accuracy: 0.5238 - val_loss: 2.1788 - val_accuracy: 0.4860
# Epoch 44/50
# 1407/1407 [==============================] - 9s 7ms/step - loss: 1.9357 - accuracy: 0.5267 - val_loss: 2.2025 - val_accuracy: 0.4884
# Epoch 45/50
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.9258 - accuracy: 0.5318 - val_loss: 2.1762 - val_accuracy: 0.4902
# Epoch 46/50
# 1407/1407 [==============================] - 9s 7ms/step - loss: 1.9281 - accuracy: 0.5320 - val_loss: 2.2146 - val_accuracy: 0.4856
# Epoch 47/50
# 1407/1407 [==============================] - 9s 7ms/step - loss: 1.9152 - accuracy: 0.5342 - val_loss: 2.2213 - val_accuracy: 0.4830
# Epoch 48/50
# 1407/1407 [==============================] - 9s 7ms/step - loss: 1.8990 - accuracy: 0.5394 - val_loss: 2.1819 - val_accuracy: 0.4806
# Epoch 49/50
# 1407/1407 [==============================] - 9s 7ms/step - loss: 1.8996 - accuracy: 0.5350 - val_loss: 2.1815 - val_accuracy: 0.4890
# Epoch 50/50
# 1407/1407 [==============================] - 9s 6ms/step - loss: 1.8944 - accuracy: 0.5411 - val_loss: 2.1982 - val_accuracy: 0.4880

# %%
# Evaluate it on a set the model has never seen
model.evaluate(X_test, y_test)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 2.1556 - accuracy: 0.5032
# [2.1555662155151367, 0.5031999945640564]
